# %% [markdown]
# # Web Mining and Applied NLP (44-620)
#
# ## Matplotlib and pyplot
#
# ### Student Name: Olakunle Alabi
#
# Perform the tasks described in the Markdown cells below.  When you have completed the assignment make sure your code cells have all been run (and have output beneath them) and ensure you have committed and pushed ALL of your changes to your assignment repository.
#
# Every question that requires you to write code will have a code cell underneath it; you may either write your entire solution in that cell or write it in a python file (`.py`), then import and run the appropriate code to answer the question.
#
# Do not use other external modules except `matplotlib` and `pyplot` (e.g. `math`, etc) for this assignment unless you are explicitly instructed to, though you may use built in python functions (`min`, `max`, etc) as you wish.
#
# For all of these questions, your plots must have an appropriate title and labeled axes.  Use the Matplotlib documentation as necessary to guide you through these exercises.

# %% [markdown]
# # Question 1

# %% [markdown]
# 1. Given the text below, create a bar plot (or a horizontal bar plot) that shows the frequency distribution of characters in the string.
# A dictionary has been created for you containing the characters and the frequencies of the characters.
# Make sure your bar plot has the bars labelled correctly (with the character it represents the frequency of).

# %%
from collections import Counter
from random import randint
import matplotlib.pyplot as plt

print('All prereqs installed.')
# !pip list
# Out:
# All prereqs installed.
# Package                       Version
# ----------------------------- -----------
# anyio                         3.6.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asgiref                       3.6.0
# astroid                       2.13.2
# asttokens                     2.2.1
# attrs                         22.2.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# bleach                        5.0.1
# brotlipy                      0.7.0
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            2.0.4
# colorama                      0.4.6
# comm                          0.1.2
# conda                         22.11.1
# conda-content-trust           0.1.3
# conda-package-handling        2.0.2
# conda_package_streaming       0.7.0
# cryptography                  38.0.4
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.3.6
# Django                        4.1.5
# dodgy                         0.2.1
# entrypoints                   0.4
# executing                     1.2.0
# fastjsonschema                2.16.2
# flake8                        4.0.1
# flake8-polyfill               1.0.2
# flit_core                     3.8.0
# fonttools                     4.25.0
# idna                          3.4
# importlib-metadata            6.0.0
# importlib-resources           5.10.2
# ipykernel                     6.20.1
# ipympl                        0.9.2
# ipython                       8.8.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.4
# isort                         5.11.4
# jedi                          0.18.2
# Jinja2                        3.1.2
# json5                         0.9.5
# jsonschema                    4.17.3
# jupyter_client                7.4.9
# jupyter_core                  5.1.3
# jupyter-server                1.23.5
# jupyterlab                    3.5.2
# jupyterlab-pygments           0.2.2
# jupyterlab_server             2.19.0
# jupyterlab-widgets            3.0.5
# kiwisolver                    1.4.4
# lazy-object-proxy             1.6.0
# logilab-common                1.7.3
# MarkupSafe                    2.1.1
# matplotlib                    3.5.3
# matplotlib-inline             0.1.6
# mccabe                        0.6.1
# menuinst                      1.4.19
# mistune                       2.0.4
# munkres                       1.1.4
# mypy-extensions               0.4.3
# nb-conda-kernels              2.3.1
# nbclassic                     0.4.8
# nbclient                      0.7.2
# nbconvert                     7.2.7
# nbformat                      5.7.3
# nest-asyncio                  1.5.6
# notebook                      6.5.2
# notebook_shim                 0.2.2
# numpy                         1.22.3
# packaging                     23.0
# pandas                        1.5.2
# pandocfilters                 1.5.0
# parso                         0.8.3
# patsy                         0.5.3
# pep8-naming                   0.10.0
# pickleshare                   0.7.5
# Pillow                        9.3.0
# pip                           22.3.1
# pkgutil_resolve_name          1.3.10
# platformdirs                  2.6.2
# pluggy                        1.0.0
# pooch                         1.6.0
# prometheus-client             0.15.0
# prompt-toolkit                3.0.36
# prospector                    1.7.7
# psutil                        5.9.0
# pure-eval                     0.2.2
# pycodestyle                   2.8.0
# pycosat                       0.6.4
# pycparser                     2.21
# pydocstyle                    6.2.2
# pyflakes                      2.4.0
# Pygments                      2.14.0
# pylint                        2.15.10
# pylint-celery                 0.3
# pylint-django                 2.5.3
# pylint-flask                  0.6
# pylint-plugin-utils           0.7
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# python-dateutil               2.8.2
# pytz                          2022.7.1
# pywin32                       305.1
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         23.2.0
# requests                      2.28.1
# requirements-detector         0.7
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# scipy                         1.10.0
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# setoptconf-tmp                0.3.1
# setuptools                    65.5.0
# sip                           4.19.13
# six                           1.16.0
# sniffio                       1.3.0
# snowballstemmer               2.2.0
# soupsieve                     2.3.2.post1
# sqlparse                      0.4.3
# stack-data                    0.6.2
# statsmodels                   0.13.5
# terminado                     0.15.0
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.6
# toolz                         0.12.0
# tornado                       6.2
# tqdm                          4.64.1
# traitlets                     5.8.1
# typing_extensions             4.4.0
# urllib3                       1.26.13
# wcwidth                       0.2.6
# webencodings                  0.5.1
# websocket-client              1.4.2
# wheel                         0.37.1
# widgetsnbextension            4.0.5
# win-inet-pton                 1.1.0
# wincertstore                  0.2
# wrapt                         1.14.1
# zipp                          3.11.0
# zstandard                     0.18.0

# %%
from collections import Counter
TEXT = "At three o’clock precisely I was at Baker Street, but Holmes had not yet returned. The landlady informed me that he had left the house shortly after eight o’clock in the morning. I sat down beside the fire, however, with the intention of awaiting him, however long he might be. I was already deeply interested in his inquiry, for, though it was surrounded by none of the grim and strange features which were associated with the two crimes which I have already recorded, still, the nature of the case and the exalted station of his client gave it a character of its own. Indeed, apart from the nature of the investigation which my friend had on hand, there was something in his masterly grasp of a situation, and his keen, incisive reasoning, which made it a pleasure to me to study his system of work, and to follow the quick, subtle methods by which he disentangled the most inextricable mysteries. So accustomed was I to his invariable success that the very possibility of his failing had ceased to enter into my head.".lower()
letter_freq = dict(Counter(TEXT))

# make a bar plot with an appropriate title, correct xtick labels, and labeled axes

# %%
import matplotlib.pyplot as plt
import collections

TEXT = "At three o’clock precisely I was at Baker Street, but Holmes had not yet returned. The landlady informed me that he had left the house shortly after eight o’clock in the morning. I sat down beside the fire, however, with the intention of awaiting him, however long he might be. I was already deeply interested in his inquiry, for, though it was surrounded by none of the grim and strange features which were associated with the two crimes which I have already recorded, still, the nature of the case and the exalted station of his client gave it a character of its own. Indeed, apart from the nature of the investigation which my friend had on hand, there was something in his masterly grasp of a situation, and his keen, incisive reasoning, which made it a pleasure to me to study his system of work, and to follow the quick, subtle methods by which he disentangled the most inextricable mysteries. So accustomed was I to his invariable success that the very possibility of his failing had ceased to enter into my head.".lower()
letter_freq = dict(collections.Counter(TEXT))

# Create a bar plot
plt.bar(letter_freq.keys(), letter_freq.values())

# Add a title
plt.title("Letter Frequency in 'The Hound of the Baskervilles'")

# Add xtick labels
plt.xticks(letter_freq.keys())

# Label axes
plt.xlabel("Letter")
plt.ylabel("Frequency")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\category.py:68, in StrCategoryConverter.convert(value, unit, axis)
#      67 # force an update so it also does type checking
# ---> 68 unit.update(values)
#      69 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\category.py:225, in UnitData.update(self, data)
#     224 convertible = True
# --> 225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
#     227     _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'dict_keys'
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[3], line 14
#      11 plt.title("Letter Frequency in 'The Hound of the Baskervilles'")
#      13 # Add xtick labels
# ---> 14 plt.xticks(letter_freq.keys())
#      16 # Label axes
#      17 plt.xlabel("Letter")
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\pyplot.py:1807, in xticks(ticks, labels, **kwargs)
#    1804         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    1805                         "without setting 'ticks'")
#    1806 else:
# -> 1807     locs = ax.set_xticks(ticks)
#    1809 if labels is None:
#    1810     labels = ax.get_xticklabels()
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\axis.py:1855, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    1829 def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#    1830     """
#    1831     Set this Axis' tick locations and optionally labels.
#    1832
#    (...)
#    1853     ticks.
#    1854     """
# -> 1855     result = self._set_tick_locations(ticks, minor=minor)
#    1856     if labels is not None:
#    1857         self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\axis.py:1804, in Axis._set_tick_locations(self, ticks, minor)
#    1800 def _set_tick_locations(self, ticks, *, minor=False):
#    1801     # see docstring of set_ticks
#    1802
#    1803     # XXX if the user changes units, the information will be lost here
# -> 1804     ticks = self.convert_units(ticks)
#    1805     for name, axis in self.axes._get_axis_map().items():
#    1806         if self is axis:
#
# File c:\Users\Admin\miniconda3\lib\site-packages\matplotlib\axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: dict_keys(['a', 't', ' ', 'h', 'r', 'e', 'o', '’', 'c', 'l', 'k', 'p', 'i', 's', 'y', 'w', 'b', ',', 'u', 'm', 'd', 'n', '.', 'f', 'g', 'v', 'q', 'x'])

# %% [markdown]
# 2. Generate a sequence of at least 5 random numbers (integers are fine), and visualize the data using both `scatter` and `plot` on different axes.  You may use the index of the value as its x value in the plot.

# %%
import random
import matplotlib.pyplot as plt

# Generate a sequence of 5 random numbers
numbers = [random.randint(1, 100) for _ in range(5)]

# Create a scatter plot
plt.scatter(range(len(numbers)), numbers)

# Create a line plot
plt.plot(range(len(numbers)), numbers)

# Add a title
plt.title("Random Numbers")

# Label axes
plt.xlabel("Index")
plt.ylabel("Number")

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(range(len(numbers)), numbers)

# %% [markdown]
# 3. Do the same question as above, but change the syle and color of both the scatter and the plot.

# %%
import random
import matplotlib.pyplot as plt

# Generate a sequence of 5 random numbers
numbers = [random.randint(1, 100) for _ in range(5)]

# Create a scatter plot with blue circles
plt.scatter(range(len(numbers)), numbers, color='blue', marker='o')

# Create a line plot with red triangles
plt.plot(range(len(numbers)), numbers, color='red', marker='^')

# Add a title
plt.title("Random Numbers")

# Label axes
plt.xlabel("Index")
plt.ylabel("Number")

# Show the plot
plt.show()

# %%
# Create a scatter plot with blue circles
plt.scatter(range(len(numbers)), numbers, color='red', marker='*')

# %% [markdown]
# 4. Given the data sets below, plot or scatter both on the same set of axes.  You are plotting the time it takes to execute a sorting algorithm on a list of a given size; your x axis should be the size, and the y axis is time.  Assume that `insertion_sort_times[i]` is how long it took to sort a list of length `sizes[i]`.  Add a legend to your plot showing which is insertion sort and which is merge sort.  Use the variable names to determine which data is which.

# %%
sizes = [10, 20, 50, 100, 1000, 5000]
insertion_sort_times = [0.0010252999999999998, 0.0027026999999999954, 0.010147200000000002, 0.0381137, 3.6303399, 91.2180796]
merge_sort_times = [0.00161889999999687, 0.003635600000009731, 0.0090655000000055, 0.020108000000007564, 0.2687474000000094, 1.6147050999999948]

# %%
import matplotlib.pyplot as plt

# Create a list of sizes
sizes = [10, 20, 50, 100, 1000, 5000]

# Create a list of insertion sort times
insertion_sort_times = [0.0010252999999999998, 0.0027026999999999954, 0.010147200000000002, 0.0381137, 3.6303399, 91.2180796]

# Create a list of merge sort times
merge_sort_times = [0.00161889999999687, 0.003635600000009731, 0.0090655000000055, 0.020108000000007564, 0.2687474000000094, 1.6147050999999948]

# Create a plot
plt.plot(sizes, insertion_sort_times, label='Insertion Sort')
plt.plot(sizes, merge_sort_times, label='Merge Sort')

# Add a title
plt.title('Sorting Time vs. List Size')

# Add x-axis and y-axis labels
plt.xlabel('List Size')
plt.ylabel('Time (seconds)')

# Add a legend
plt.legend()

# Show the plot
plt.show()
